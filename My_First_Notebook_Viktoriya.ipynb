# %% [markdown]
# # My First Jupyter Notebook My first markdown cell in Jupyter.
# This notebook was created to practice using Markdown and Python code cells in Google Colab.

# %%
print("Hello, World! I am using Google Colab.")
# Out:
# Hello, World! I am using Google Colab.
